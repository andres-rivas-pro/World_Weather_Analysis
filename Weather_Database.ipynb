# %%
import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd 
from datetime import datetime

from config import weather_api_key
from config import g_key

# %%
# Generate 1,500 random latitudes and longitudes, and zip them as a list of tuples
lats = np.random.uniform(-90.0,90.0, size=1500)
lngs = np.random.uniform(-180.0,180.0,size=1500)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# Get the nearest city using the citipy module.
cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0],coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
print(cities[:10], 'Generate', len(cities))
# Out:
# ['rikitea', 'puerto ayora', 'dikson', 'maceio', 'cidreira', 'nikolskoye', 'hilo', 'new norfolk', 'punta arenas', 'kutum'] Generate 606

# %%
# Perform an API call with the OpenWeatherMap.

# initial counters for log and sets
record_count = 1 
set_count = 1

city_data = list()
basic_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")
# use enumerate() method to loop index and item simutanously 
for i, item in enumerate(cities):
    if i % 50 == 0 and i != 0 :
        record_count = 1  
        set_count +=1 
    # build URL for API call
    url = basic_url + '&q=' + item
    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {item}')
    # increment record count
    record_count +=1

    try:
        js = requests.get(url).json()
        city_name = item
        city_country = js['sys']['country']
        city_UTCdate = js['dt']
        city_date = datetime.utcfromtimestamp(city_UTCdate).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = js['coord']['lat']
        city_lon = js['coord']['lon']
        city_max_temp = js['main']['temp_max']
        city_humidity = js['main']['humidity']
        city_cload = js['clouds']['all']
        city_wind_speed = js['wind']['speed']
        city_weather_description = js['weather'][0]['description']

        # raining info
        try:
            js['weather'][0]['main'] == 'Rain'
            city_rain = js['rain']['3h']
        except:
            city_rain = 0.000

        # snowing info
        try:
            js['weather'][0]['main'] == 'Snow'
            city_snow = js['snow']['3h']
        except:
            city_snow = 0    

        # append as a list of dictionaries
        city_data.append({'City':city_name, 'Country':city_country, 'Date':city_date, 
                        'Lat':city_lat, 'Lng': city_lon,'Max Temp':city_max_temp,
                        'Humidity':city_humidity,'Cloudiness': city_cload,'Wind Speed':city_wind_speed,
                        'Current Description':city_weather_description,
                        'Rain inches (last 3 hrs)':city_rain,'Snow inches (last 3 hrs)':city_snow})
    except:
        print("City not found. Skipping...")
        pass
print('-------------------------------')
print('Data Retrieval Complete        ')
print('-------------------------------')

print(len(city_data))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | dikson
# Processing Record 4 of Set 1 | maceio
# Processing Record 5 of Set 1 | cidreira
# Processing Record 6 of Set 1 | nikolskoye
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | kutum
# Processing Record 11 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 1 | pangnirtung
# Processing Record 13 of Set 1 | severo-kurilsk
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | ponta do sol
# Processing Record 16 of Set 1 | port hardy
# Processing Record 17 of Set 1 | coquimbo
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | georgetown
# Processing Record 21 of Set 1 | atar
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | lorengau
# Processing Record 24 of Set 1 | grand gaube
# Processing Record 25 of Set 1 | urucui
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | sakakah
# Processing Record 30 of Set 1 | kavaratti
# Processing Record 31 of Set 1 | banda aceh
# Processing Record 32 of Set 1 | ternate
# Processing Record 33 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 1 | barrow
# Processing Record 35 of Set 1 | abha
# Processing Record 36 of Set 1 | airai
# Processing Record 37 of Set 1 | hasaki
# Processing Record 38 of Set 1 | cherskiy
# Processing Record 39 of Set 1 | salalah
# Processing Record 40 of Set 1 | tual
# Processing Record 41 of Set 1 | esperance
# Processing Record 42 of Set 1 | upernavik
# Processing Record 43 of Set 1 | nishihara
# Processing Record 44 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 1 | manzhouli
# Processing Record 46 of Set 1 | tuktoyaktuk
# Processing Record 47 of Set 1 | saint-philippe
# Processing Record 48 of Set 1 | touros
# Processing Record 49 of Set 1 | kaitangata
# Processing Record 50 of Set 1 | bathsheba
# Processing Record 1 of Set 2 | asau
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | atuona
# Processing Record 4 of Set 2 | khatanga
# Processing Record 5 of Set 2 | thunder bay
# Processing Record 6 of Set 2 | bairiki
# Processing Record 7 of Set 2 | brenham
# Processing Record 8 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 2 | tasiilaq
# Processing Record 10 of Set 2 | viedma
# Processing Record 11 of Set 2 | shimoda
# Processing Record 12 of Set 2 | butaritari
# Processing Record 13 of Set 2 | meulaboh
# Processing Record 14 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 2 | manavgat
# Processing Record 16 of Set 2 | kungurtug
# Processing Record 17 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 18 of Set 2 | balkhash
# Processing Record 19 of Set 2 | clyde river
# Processing Record 20 of Set 2 | kemijarvi
# Processing Record 21 of Set 2 | alofi
# Processing Record 22 of Set 2 | nelson bay
# Processing Record 23 of Set 2 | nome
# Processing Record 24 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 2 | barabai
# Processing Record 26 of Set 2 | hudiksvall
# Processing Record 27 of Set 2 | ahipara
# Processing Record 28 of Set 2 | kapaa
# Processing Record 29 of Set 2 | garm
# City not found. Skipping...
# Processing Record 30 of Set 2 | mataura
# Processing Record 31 of Set 2 | kashi
# Processing Record 32 of Set 2 | volkach
# Processing Record 33 of Set 2 | lebu
# Processing Record 34 of Set 2 | kavieng
# Processing Record 35 of Set 2 | wagar
# Processing Record 36 of Set 2 | mala tokmachka
# Processing Record 37 of Set 2 | matai
# Processing Record 38 of Set 2 | port lincoln
# Processing Record 39 of Set 2 | adrian
# Processing Record 40 of Set 2 | bandarbeyla
# Processing Record 41 of Set 2 | castro
# Processing Record 42 of Set 2 | avera
# Processing Record 43 of Set 2 | hobyo
# Processing Record 44 of Set 2 | kidal
# Processing Record 45 of Set 2 | hobart
# Processing Record 46 of Set 2 | azimur
# City not found. Skipping...
# Processing Record 47 of Set 2 | marawi
# Processing Record 48 of Set 2 | weligama
# Processing Record 49 of Set 2 | zlobin
# Processing Record 50 of Set 2 | hohhot
# Processing Record 1 of Set 3 | novaya ladoga
# Processing Record 2 of Set 3 | port alfred
# Processing Record 3 of Set 3 | sao filipe
# Processing Record 4 of Set 3 | constitucion
# Processing Record 5 of Set 3 | el faiyum
# City not found. Skipping...
# Processing Record 6 of Set 3 | pisco
# Processing Record 7 of Set 3 | wasilla
# Processing Record 8 of Set 3 | deputatskiy
# Processing Record 9 of Set 3 | kodiak
# Processing Record 10 of Set 3 | baft
# Processing Record 11 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 3 | carnarvon
# Processing Record 13 of Set 3 | mahebourg
# Processing Record 14 of Set 3 | ribeira grande
# Processing Record 15 of Set 3 | mandali
# Processing Record 16 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 17 of Set 3 | castelfiorentino
# Processing Record 18 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 3 | casablanca
# Processing Record 20 of Set 3 | severodvinsk
# Processing Record 21 of Set 3 | guanica
# Processing Record 22 of Set 3 | cape town
# Processing Record 23 of Set 3 | qaanaaq
# Processing Record 24 of Set 3 | dingle
# Processing Record 25 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 3 | mariselu
# Processing Record 27 of Set 3 | ilulissat
# Processing Record 28 of Set 3 | margate
# Processing Record 29 of Set 3 | thompson
# Processing Record 30 of Set 3 | kruisfontein
# Processing Record 31 of Set 3 | avarua
# Processing Record 32 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 3 | chatrapur
# Processing Record 34 of Set 3 | broken hill
# Processing Record 35 of Set 3 | duluth
# Processing Record 36 of Set 3 | sitka
# Processing Record 37 of Set 3 | eirunepe
# Processing Record 38 of Set 3 | chicama
# Processing Record 39 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 3 | dudinka
# Processing Record 41 of Set 3 | taoudenni
# Processing Record 42 of Set 3 | bengkulu
# Processing Record 43 of Set 3 | ye
# City not found. Skipping...
# Processing Record 44 of Set 3 | dunmore east
# Processing Record 45 of Set 3 | mehamn
# Processing Record 46 of Set 3 | cahabon
# Processing Record 47 of Set 3 | arraial do cabo
# Processing Record 48 of Set 3 | college
# Processing Record 49 of Set 3 | general roca
# Processing Record 50 of Set 3 | kununurra
# Processing Record 1 of Set 4 | chokurdakh
# Processing Record 2 of Set 4 | luderitz
# Processing Record 3 of Set 4 | paamiut
# Processing Record 4 of Set 4 | provideniya
# Processing Record 5 of Set 4 | nanortalik
# Processing Record 6 of Set 4 | hermanus
# Processing Record 7 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 4 | rodrigues alves
# Processing Record 9 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 4 | namibe
# Processing Record 11 of Set 4 | kindu
# Processing Record 12 of Set 4 | port blair
# Processing Record 13 of Set 4 | bambous virieux
# Processing Record 14 of Set 4 | daru
# Processing Record 15 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 16 of Set 4 | cabo san lucas
# Processing Record 17 of Set 4 | yarega
# Processing Record 18 of Set 4 | bundaberg
# Processing Record 19 of Set 4 | torbay
# Processing Record 20 of Set 4 | mumford
# Processing Record 21 of Set 4 | bredasdorp
# Processing Record 22 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 4 | victoria
# Processing Record 24 of Set 4 | ambon
# Processing Record 25 of Set 4 | basqal
# Processing Record 26 of Set 4 | aleksandrov gay
# Processing Record 27 of Set 4 | camacha
# Processing Record 28 of Set 4 | yellamanchili
# City not found. Skipping...
# Processing Record 29 of Set 4 | tura
# Processing Record 30 of Set 4 | egvekinot
# Processing Record 31 of Set 4 | santa cruz cabralia
# Processing Record 32 of Set 4 | nesbyen
# Processing Record 33 of Set 4 | gat
# Processing Record 34 of Set 4 | caravelas
# Processing Record 35 of Set 4 | abaza
# Processing Record 36 of Set 4 | ocos
# Processing Record 37 of Set 4 | qabis
# City not found. Skipping...
# Processing Record 38 of Set 4 | vila velha
# Processing Record 39 of Set 4 | gardner
# Processing Record 40 of Set 4 | sao joao da barra
# Processing Record 41 of Set 4 | bethel
# Processing Record 42 of Set 4 | tautira
# Processing Record 43 of Set 4 | korla
# Processing Record 44 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 45 of Set 4 | ngaoundere
# Processing Record 46 of Set 4 | mpongwe
# Processing Record 47 of Set 4 | faanui
# Processing Record 48 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 49 of Set 4 | bonavista
# Processing Record 50 of Set 4 | port hedland
# Processing Record 1 of Set 5 | auki
# Processing Record 2 of Set 5 | wonthaggi
# Processing Record 3 of Set 5 | north bend
# Processing Record 4 of Set 5 | norman wells
# Processing Record 5 of Set 5 | batagay-alyta
# Processing Record 6 of Set 5 | porbandar
# Processing Record 7 of Set 5 | johi
# Processing Record 8 of Set 5 | ponta delgada
# Processing Record 9 of Set 5 | loandjili
# Processing Record 10 of Set 5 | soavinandriana
# Processing Record 11 of Set 5 | klaksvik
# Processing Record 12 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 13 of Set 5 | coihaique
# Processing Record 14 of Set 5 | porto walter
# Processing Record 15 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 16 of Set 5 | coronel bogado
# Processing Record 17 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 18 of Set 5 | catalina foothills
# Processing Record 19 of Set 5 | oudtshoorn
# Processing Record 20 of Set 5 | macaboboni
# City not found. Skipping...
# Processing Record 21 of Set 5 | souillac
# Processing Record 22 of Set 5 | bilibino
# Processing Record 23 of Set 5 | fortuna
# Processing Record 24 of Set 5 | kenora
# Processing Record 25 of Set 5 | quatre cocos
# Processing Record 26 of Set 5 | hualmay
# Processing Record 27 of Set 5 | ayna
# Processing Record 28 of Set 5 | ilhabela
# Processing Record 29 of Set 5 | empangeni
# Processing Record 30 of Set 5 | chilca
# Processing Record 31 of Set 5 | chapadinha
# Processing Record 32 of Set 5 | bolshiye uki
# City not found. Skipping...
# Processing Record 33 of Set 5 | cap-aux-meules
# Processing Record 34 of Set 5 | nhulunbuy
# Processing Record 35 of Set 5 | kupang
# Processing Record 36 of Set 5 | burnie
# Processing Record 37 of Set 5 | dunedin
# Processing Record 38 of Set 5 | padang
# Processing Record 39 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 5 | krasnoarmeysk
# Processing Record 41 of Set 5 | jalu
# Processing Record 42 of Set 5 | linares
# Processing Record 43 of Set 5 | sumenep
# Processing Record 44 of Set 5 | ketchikan
# Processing Record 45 of Set 5 | port hawkesbury
# Processing Record 46 of Set 5 | sechura
# Processing Record 47 of Set 5 | lompoc
# Processing Record 48 of Set 5 | srednekolymsk
# Processing Record 49 of Set 5 | pachino
# Processing Record 50 of Set 5 | saint-denis
# Processing Record 1 of Set 6 | rawson
# Processing Record 2 of Set 6 | le port
# Processing Record 3 of Set 6 | bayan
# Processing Record 4 of Set 6 | comodoro rivadavia
# Processing Record 5 of Set 6 | killybegs
# Processing Record 6 of Set 6 | caucaia
# Processing Record 7 of Set 6 | okha
# Processing Record 8 of Set 6 | neftekamsk
# Processing Record 9 of Set 6 | talnakh
# Processing Record 10 of Set 6 | ustynivka
# Processing Record 11 of Set 6 | marquette
# Processing Record 12 of Set 6 | naze
# Processing Record 13 of Set 6 | vesyegonsk
# Processing Record 14 of Set 6 | huarmey
# Processing Record 15 of Set 6 | olafsvik
# Processing Record 16 of Set 6 | alenquer
# Processing Record 17 of Set 6 | ambilobe
# Processing Record 18 of Set 6 | pevek
# Processing Record 19 of Set 6 | baykit
# Processing Record 20 of Set 6 | badou
# Processing Record 21 of Set 6 | saint anthony
# Processing Record 22 of Set 6 | okhotsk
# Processing Record 23 of Set 6 | longavi
# Processing Record 24 of Set 6 | san cristobal
# Processing Record 25 of Set 6 | dakar
# Processing Record 26 of Set 6 | inhambane
# Processing Record 27 of Set 6 | cabanbanan
# Processing Record 28 of Set 6 | chuy
# Processing Record 29 of Set 6 | sola
# Processing Record 30 of Set 6 | karamea
# City not found. Skipping...
# Processing Record 31 of Set 6 | dekar
# Processing Record 32 of Set 6 | bajil
# Processing Record 33 of Set 6 | dangriga
# Processing Record 34 of Set 6 | leningradskiy
# Processing Record 35 of Set 6 | vredendal
# Processing Record 36 of Set 6 | sept-iles
# Processing Record 37 of Set 6 | mackay
# Processing Record 38 of Set 6 | komsomolskiy
# Processing Record 39 of Set 6 | wahiawa
# Processing Record 40 of Set 6 | podujevo
# Processing Record 41 of Set 6 | mamou
# Processing Record 42 of Set 6 | hedensted
# Processing Record 43 of Set 6 | saint george
# Processing Record 44 of Set 6 | vao
# Processing Record 45 of Set 6 | magistralnyy
# Processing Record 46 of Set 6 | khani
# Processing Record 47 of Set 6 | vestmannaeyjar
# Processing Record 48 of Set 6 | aklavik
# Processing Record 49 of Set 6 | morondava
# Processing Record 50 of Set 6 | kualakapuas
# Processing Record 1 of Set 7 | tuatapere
# Processing Record 2 of Set 7 | sol-iletsk
# Processing Record 3 of Set 7 | fairbanks
# Processing Record 4 of Set 7 | peniche
# Processing Record 5 of Set 7 | hammerfest
# Processing Record 6 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 7 | ixtapa
# Processing Record 8 of Set 7 | gull lake
# Processing Record 9 of Set 7 | pechenga
# Processing Record 10 of Set 7 | beringovskiy
# Processing Record 11 of Set 7 | codrington
# Processing Record 12 of Set 7 | oranjestad
# Processing Record 13 of Set 7 | zeitz
# Processing Record 14 of Set 7 | shelburne
# Processing Record 15 of Set 7 | sibu
# Processing Record 16 of Set 7 | arroio dos ratos
# Processing Record 17 of Set 7 | kokoda
# Processing Record 18 of Set 7 | zhanaozen
# Processing Record 19 of Set 7 | hovd
# Processing Record 20 of Set 7 | port elizabeth
# Processing Record 21 of Set 7 | traverse city
# Processing Record 22 of Set 7 | cayenne
# Processing Record 23 of Set 7 | oxford
# Processing Record 24 of Set 7 | beloha
# Processing Record 25 of Set 7 | umea
# Processing Record 26 of Set 7 | djambala
# Processing Record 27 of Set 7 | opuwo
# Processing Record 28 of Set 7 | flinders
# Processing Record 29 of Set 7 | sangar
# Processing Record 30 of Set 7 | henties bay
# Processing Record 31 of Set 7 | mahibadhoo
# Processing Record 32 of Set 7 | saskylakh
# Processing Record 33 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 7 | raga
# Processing Record 35 of Set 7 | vardo
# Processing Record 36 of Set 7 | hofn
# Processing Record 37 of Set 7 | dipkarpaz
# City not found. Skipping...
# Processing Record 38 of Set 7 | shingu
# Processing Record 39 of Set 7 | mitsamiouli
# Processing Record 40 of Set 7 | waipawa
# Processing Record 41 of Set 7 | sarangani
# Processing Record 42 of Set 7 | dalvik
# Processing Record 43 of Set 7 | namatanai
# Processing Record 44 of Set 7 | bojonegoro
# Processing Record 45 of Set 7 | kangaatsiaq
# Processing Record 46 of Set 7 | bukene
# Processing Record 47 of Set 7 | geresk
# City not found. Skipping...
# Processing Record 48 of Set 7 | faya
# Processing Record 49 of Set 7 | marzuq
# Processing Record 50 of Set 7 | havelock
# Processing Record 1 of Set 8 | kamenka
# Processing Record 2 of Set 8 | havre-saint-pierre
# Processing Record 3 of Set 8 | saldanha
# Processing Record 4 of Set 8 | kostino
# Processing Record 5 of Set 8 | brainerd
# Processing Record 6 of Set 8 | soyo
# Processing Record 7 of Set 8 | kloulklubed
# Processing Record 8 of Set 8 | isangel
# Processing Record 9 of Set 8 | pimentel
# Processing Record 10 of Set 8 | ostersund
# Processing Record 11 of Set 8 | mogadishu
# Processing Record 12 of Set 8 | ancud
# Processing Record 13 of Set 8 | tabuk
# Processing Record 14 of Set 8 | nchelenge
# Processing Record 15 of Set 8 | vila franca do campo
# Processing Record 16 of Set 8 | verkhnevilyuysk
# Processing Record 17 of Set 8 | walla walla
# Processing Record 18 of Set 8 | pangkalanbuun
# Processing Record 19 of Set 8 | knysna
# Processing Record 20 of Set 8 | grindavik
# Processing Record 21 of Set 8 | chipata
# Processing Record 22 of Set 8 | mar del plata
# Processing Record 23 of Set 8 | nyurba
# Processing Record 24 of Set 8 | clairmont
# Processing Record 25 of Set 8 | trapani
# Processing Record 26 of Set 8 | batticaloa
# Processing Record 27 of Set 8 | kimbe
# Processing Record 28 of Set 8 | mahajanga
# Processing Record 29 of Set 8 | bagdarin
# Processing Record 30 of Set 8 | palmer
# Processing Record 31 of Set 8 | oussouye
# Processing Record 32 of Set 8 | mae hong son
# Processing Record 33 of Set 8 | iquique
# Processing Record 34 of Set 8 | turka
# Processing Record 35 of Set 8 | le mars
# Processing Record 36 of Set 8 | zelenoborsk
# Processing Record 37 of Set 8 | mangan
# Processing Record 38 of Set 8 | rusape
# Processing Record 39 of Set 8 | filadelfia
# Processing Record 40 of Set 8 | kiruna
# Processing Record 41 of Set 8 | vinh
# Processing Record 42 of Set 8 | guadalupe y calvo
# Processing Record 43 of Set 8 | guerrero negro
# Processing Record 44 of Set 8 | igarka
# Processing Record 45 of Set 8 | am timan
# Processing Record 46 of Set 8 | manggar
# Processing Record 47 of Set 8 | finnsnes
# Processing Record 48 of Set 8 | orshanka
# Processing Record 49 of Set 8 | visby
# Processing Record 50 of Set 8 | coxim
# Processing Record 1 of Set 9 | san patricio
# Processing Record 2 of Set 9 | cornelio procopio
# Processing Record 3 of Set 9 | tingo maria
# Processing Record 4 of Set 9 | san isidro
# Processing Record 5 of Set 9 | boyolangu
# Processing Record 6 of Set 9 | agadez
# Processing Record 7 of Set 9 | sandanski
# Processing Record 8 of Set 9 | dom pedrito
# Processing Record 9 of Set 9 | veraval
# Processing Record 10 of Set 9 | cruzeiro do sul
# Processing Record 11 of Set 9 | tigil
# Processing Record 12 of Set 9 | takoradi
# Processing Record 13 of Set 9 | ilheus
# Processing Record 14 of Set 9 | bayangol
# Processing Record 15 of Set 9 | isla mujeres
# Processing Record 16 of Set 9 | hindoria
# Processing Record 17 of Set 9 | broome
# Processing Record 18 of Set 9 | chaohu
# Processing Record 19 of Set 9 | yerbogachen
# Processing Record 20 of Set 9 | solnechnyy
# Processing Record 21 of Set 9 | los llanos de aridane
# Processing Record 22 of Set 9 | nantucket
# Processing Record 23 of Set 9 | joshimath
# Processing Record 24 of Set 9 | mahanoro
# Processing Record 25 of Set 9 | seoul
# Processing Record 26 of Set 9 | port-de-paix
# City not found. Skipping...
# Processing Record 27 of Set 9 | san policarpo
# Processing Record 28 of Set 9 | san quintin
# Processing Record 29 of Set 9 | san mateo ixtatan
# Processing Record 30 of Set 9 | qaqortoq
# Processing Record 31 of Set 9 | sandnessjoen
# Processing Record 32 of Set 9 | cocorit
# Processing Record 33 of Set 9 | baloi
# Processing Record 34 of Set 9 | yar-sale
# Processing Record 35 of Set 9 | santa cruz
# Processing Record 36 of Set 9 | perth
# Processing Record 37 of Set 9 | tigzirt
# Processing Record 38 of Set 9 | haines junction
# Processing Record 39 of Set 9 | beihai
# Processing Record 40 of Set 9 | lavrentiya
# Processing Record 41 of Set 9 | lensk
# Processing Record 42 of Set 9 | yulara
# Processing Record 43 of Set 9 | rocha
# Processing Record 44 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 9 | puerto suarez
# Processing Record 46 of Set 9 | satka
# Processing Record 47 of Set 9 | borogontsy
# Processing Record 48 of Set 9 | ouahigouya
# Processing Record 49 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 50 of Set 9 | tocopilla
# Processing Record 1 of Set 10 | cullman
# Processing Record 2 of Set 10 | agaro
# Processing Record 3 of Set 10 | la palma
# Processing Record 4 of Set 10 | allapalli
# Processing Record 5 of Set 10 | chamba
# Processing Record 6 of Set 10 | necochea
# Processing Record 7 of Set 10 | hounde
# Processing Record 8 of Set 10 | were ilu
# Processing Record 9 of Set 10 | farnham
# Processing Record 10 of Set 10 | yazman
# Processing Record 11 of Set 10 | todos santos
# Processing Record 12 of Set 10 | zhigansk
# Processing Record 13 of Set 10 | mayumba
# Processing Record 14 of Set 10 | akyab
# Processing Record 15 of Set 10 | ylivieska
# Processing Record 16 of Set 10 | baherden
# Processing Record 17 of Set 10 | great falls
# Processing Record 18 of Set 10 | ulladulla
# Processing Record 19 of Set 10 | east london
# Processing Record 20 of Set 10 | kuytun
# Processing Record 21 of Set 10 | paita
# Processing Record 22 of Set 10 | kuah
# Processing Record 23 of Set 10 | aden
# Processing Record 24 of Set 10 | pak phanang
# Processing Record 25 of Set 10 | qasigiannguit
# Processing Record 26 of Set 10 | gondanglegi
# Processing Record 27 of Set 10 | qingquan
# Processing Record 28 of Set 10 | kiunga
# Processing Record 29 of Set 10 | mitchell
# Processing Record 30 of Set 10 | obodivka
# Processing Record 31 of Set 10 | staryy nadym
# Processing Record 32 of Set 10 | naberera
# Processing Record 33 of Set 10 | manjacaze
# Processing Record 34 of Set 10 | lagoa
# Processing Record 35 of Set 10 | dolgorukovo
# Processing Record 36 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 37 of Set 10 | pangani
# Processing Record 38 of Set 10 | gravdal
# Processing Record 39 of Set 10 | wawa
# Processing Record 40 of Set 10 | tiksi
# Processing Record 41 of Set 10 | zhezkazgan
# Processing Record 42 of Set 10 | redmond
# Processing Record 43 of Set 10 | marsa matruh
# Processing Record 44 of Set 10 | la ronge
# Processing Record 45 of Set 10 | chiselet
# Processing Record 46 of Set 10 | babu
# Processing Record 47 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 48 of Set 10 | whitehorse
# Processing Record 49 of Set 10 | moiyabana
# City not found. Skipping...
# Processing Record 50 of Set 10 | half moon bay
# Processing Record 1 of Set 11 | hoi an
# Processing Record 2 of Set 11 | burica
# City not found. Skipping...
# Processing Record 3 of Set 11 | talas
# Processing Record 4 of Set 11 | miranda de ebro
# Processing Record 5 of Set 11 | shebalino
# Processing Record 6 of Set 11 | sinnamary
# Processing Record 7 of Set 11 | gizo
# Processing Record 8 of Set 11 | longyearbyen
# Processing Record 9 of Set 11 | hami
# Processing Record 10 of Set 11 | oranjemund
# Processing Record 11 of Set 11 | susehri
# Processing Record 12 of Set 11 | port augusta
# Processing Record 13 of Set 11 | alexandria
# Processing Record 14 of Set 11 | gannan
# Processing Record 15 of Set 11 | aktau
# Processing Record 16 of Set 11 | baruun-urt
# Processing Record 17 of Set 11 | narsaq
# Processing Record 18 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 19 of Set 11 | springbok
# Processing Record 20 of Set 11 | banff
# Processing Record 21 of Set 11 | mount gambier
# Processing Record 22 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 23 of Set 11 | gillette
# Processing Record 24 of Set 11 | poplar bluff
# Processing Record 25 of Set 11 | akonolinga
# Processing Record 26 of Set 11 | iqaluit
# Processing Record 27 of Set 11 | dinguiraye
# Processing Record 28 of Set 11 | vostok
# Processing Record 29 of Set 11 | acapulco
# Processing Record 30 of Set 11 | nouadhibou
# Processing Record 31 of Set 11 | zeya
# Processing Record 32 of Set 11 | eureka
# Processing Record 33 of Set 11 | tekeli
# Processing Record 34 of Set 11 | richards bay
# Processing Record 35 of Set 11 | saint-leu
# Processing Record 36 of Set 11 | kilrush
# Processing Record 37 of Set 11 | panorama
# Processing Record 38 of Set 11 | bukama
# Processing Record 39 of Set 11 | afyonkarahisar
# Processing Record 40 of Set 11 | san lawrenz
# Processing Record 41 of Set 11 | vanimo
# Processing Record 42 of Set 11 | kaeo
# Processing Record 43 of Set 11 | alugan
# Processing Record 44 of Set 11 | katangli
# Processing Record 45 of Set 11 | rio grande
# Processing Record 46 of Set 11 | mildura
# Processing Record 47 of Set 11 | noumea
# Processing Record 48 of Set 11 | eenhana
# Processing Record 49 of Set 11 | safwah
# City not found. Skipping...
# Processing Record 50 of Set 11 | tambacounda
# Processing Record 1 of Set 12 | katsuura
# Processing Record 2 of Set 12 | muisne
# Processing Record 3 of Set 12 | moctezuma
# Processing Record 4 of Set 12 | along
# Processing Record 5 of Set 12 | strezhevoy
# Processing Record 6 of Set 12 | dalby
# Processing Record 7 of Set 12 | orocovis
# Processing Record 8 of Set 12 | san jeronimo
# Processing Record 9 of Set 12 | saurimo
# Processing Record 10 of Set 12 | kalamare
# Processing Record 11 of Set 12 | ipixuna
# Processing Record 12 of Set 12 | beruwala
# Processing Record 13 of Set 12 | tynda
# Processing Record 14 of Set 12 | vidim
# Processing Record 15 of Set 12 | pacific grove
# Processing Record 16 of Set 12 | leh
# Processing Record 17 of Set 12 | jinchang
# Processing Record 18 of Set 12 | natal
# Processing Record 19 of Set 12 | waynesville
# Processing Record 20 of Set 12 | alekseyevka
# Processing Record 21 of Set 12 | rabo de peixe
# Processing Record 22 of Set 12 | maracacume
# Processing Record 23 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 12 | havoysund
# Processing Record 25 of Set 12 | tacna
# Processing Record 26 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 27 of Set 12 | hondo
# Processing Record 28 of Set 12 | carauari
# Processing Record 29 of Set 12 | cozumel
# Processing Record 30 of Set 12 | sabang
# Processing Record 31 of Set 12 | khorramshahr
# Processing Record 32 of Set 12 | tromso
# Processing Record 33 of Set 12 | buala
# Processing Record 34 of Set 12 | nova olimpia
# Processing Record 35 of Set 12 | suntar
# Processing Record 36 of Set 12 | tahe
# Processing Record 37 of Set 12 | concordia
# Processing Record 38 of Set 12 | rio gallegos
# Processing Record 39 of Set 12 | bagan
# Processing Record 40 of Set 12 | tahoua
# Processing Record 41 of Set 12 | la rioja
# Processing Record 42 of Set 12 | eyrarbakki
# Processing Record 43 of Set 12 | biltine
# Processing Record 44 of Set 12 | agirish
# Processing Record 45 of Set 12 | marsaxlokk
# Processing Record 46 of Set 12 | nurota
# Processing Record 47 of Set 12 | saint-donat-de-montcalm
# Processing Record 48 of Set 12 | maryville
# Processing Record 49 of Set 12 | marystown
# Processing Record 50 of Set 12 | shyryayeve
# Processing Record 1 of Set 13 | ihosy
# Processing Record 2 of Set 13 | anloga
# Processing Record 3 of Set 13 | revelstoke
# Processing Record 4 of Set 13 | san vicente
# Processing Record 5 of Set 13 | monrovia
# Processing Record 6 of Set 13 | kattivakkam
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# 558

# %%
#Save the new DataFrame as a CSV file
challenge_city_data_df = pd.DataFrame(city_data)
challenge_city_data_df.to_csv(path_or_buf='data/WeatherPy_challenge.csv', index_label='City_ID')

# %% [markdown]
# There were 82 cities that recorded ranfall and 11 cities that recorded snowx

# %%
# How many cities have recorded rainfall?
raining_count = challenge_city_data_df.loc[(challenge_city_data_df['Rain inches (last 3 hrs)']!=0)].count()
raining_count
# Out:
# City                        82
# Country                     82
# Date                        82
# Lat                         82
# Lng                         82
# Max Temp                    82
# Humidity                    82
# Cloudiness                  82
# Wind Speed                  82
# Current Description         82
# Rain inches (last 3 hrs)    82
# Snow inches (last 3 hrs)    82
# dtype: int64

# %%
# How many cities have recorded snow?
snowing_count = challenge_city_data_df.loc[(challenge_city_data_df['Snow inches (last 3 hrs)']!=0)].count()
snowing_count
# Out:
# City                        11
# Country                     11
# Date                        11
# Lat                         11
# Lng                         11
# Max Temp                    11
# Humidity                    11
# Cloudiness                  11
# Wind Speed                  11
# Current Description         11
# Rain inches (last 3 hrs)    11
# Snow inches (last 3 hrs)    11
# dtype: int64
