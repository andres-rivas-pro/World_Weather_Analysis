# %%
import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd 
from datetime import datetime

from config import weather_api_key
from config import g_key

# %%
# Generate 1,500 random latitudes and longitudes, and zip them as a list of tuples
lats = np.random.uniform(-90.0,90.0, size=1500)
lngs = np.random.uniform(-180.0,180.0,size=1500)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# Get the nearest city using the citipy module.
cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0],coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
print(cities[:10], 'Generate', len(cities))
# Out:
# ['mar del plata', 'katsuura', 'victoria', 'busselton', 'maykor', 'rikitea', 'lorengau', 'killybegs', 'lumsden', 'severo-kurilsk'] Generate 616

# %%
# Perform an API call with the OpenWeatherMap.

# initial counters for log and sets
record_count = 1 
set_count = 1

city_data = list()
basic_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")
# use enumerate() method to loop index and item simutanously 
for i, item in enumerate(cities):
    if i % 50 == 0 and i != 0 :
        record_count = 1  
        set_count +=1 
    # build URL for API call
    url = basic_url + '&q=' + item
    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {item}')
    # increment record count
    record_count +=1

    try:
        js = requests.get(url).json()
        city_name = item
        city_country = js['sys']['country']
        city_UTCdate = js['dt']
        city_date = datetime.utcfromtimestamp(city_UTCdate).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = js['coord']['lat']
        city_lon = js['coord']['lon']
        city_max_temp = js['main']['temp_max']
        city_humidity = js['main']['humidity']
        city_cload = js['clouds']['all']
        city_wind_speed = js['wind']['speed']
        city_weather_description = js['weather'][0]['description']

        # raining info
        try:
            js['weather'][0]['main'] == 'Rain'
            city_rain = js['rain']['3h']
        except:
            city_rain = 0.000

        # snowing info
        try:
            js['weather'][0]['main'] == 'Snow'
            city_snow = js['snow']['3h']
        except:
            city_snow = 0    

        # append as a list of dictionaries
        city_data.append({'City':city_name, 'Country':city_country, 'Date':city_date, 
                        'Lat':city_lat, 'Lng': city_lon,'Max Temp':city_max_temp,
                        'Humidity':city_humidity,'Cloudiness': city_cload,'Wind Speed':city_wind_speed,
                        'Current Description':city_weather_description,
                        'Rain inches (last 3 hrs)':city_rain,'Snow inches (last 3 hrs)':city_snow})
    except:
        print("City not found. Skipping...")
        pass
print('-------------------------------')
print('Data Retrieval Complete        ')
print('-------------------------------')

print(len(city_data))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mar del plata
# Processing Record 2 of Set 1 | katsuura
# Processing Record 3 of Set 1 | victoria
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | maykor
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | lorengau
# Processing Record 8 of Set 1 | killybegs
# Processing Record 9 of Set 1 | lumsden
# Processing Record 10 of Set 1 | severo-kurilsk
# Processing Record 11 of Set 1 | upernavik
# Processing Record 12 of Set 1 | lasa
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | provideniya
# Processing Record 15 of Set 1 | biltine
# Processing Record 16 of Set 1 | khatanga
# Processing Record 17 of Set 1 | birao
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | jurmala
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | savonlinna
# Processing Record 22 of Set 1 | lemoore
# Processing Record 23 of Set 1 | saskylakh
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | evensk
# Processing Record 26 of Set 1 | dunedin
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 1 | akyab
# Processing Record 30 of Set 1 | drumheller
# Processing Record 31 of Set 1 | yichang
# Processing Record 32 of Set 1 | ibaiti
# Processing Record 33 of Set 1 | dolores
# Processing Record 34 of Set 1 | saint-augustin
# Processing Record 35 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 1 | terrace bay
# Processing Record 37 of Set 1 | carnarvon
# Processing Record 38 of Set 1 | puerto ayora
# Processing Record 39 of Set 1 | saint-georges
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | dikson
# Processing Record 42 of Set 1 | hilo
# Processing Record 43 of Set 1 | vila velha
# Processing Record 44 of Set 1 | east london
# Processing Record 45 of Set 1 | brae
# Processing Record 46 of Set 1 | kodiak
# Processing Record 47 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 1 | half moon bay
# Processing Record 49 of Set 1 | tasiilaq
# Processing Record 50 of Set 1 | klaksvik
# Processing Record 1 of Set 2 | yar-sale
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | bredasdorp
# Processing Record 4 of Set 2 | kahului
# Processing Record 5 of Set 2 | yakima
# Processing Record 6 of Set 2 | bonthe
# Processing Record 7 of Set 2 | hofn
# Processing Record 8 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 2 | pachino
# Processing Record 11 of Set 2 | meadow lake
# Processing Record 12 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | singarayakonda
# Processing Record 15 of Set 2 | chokurdakh
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | sorland
# Processing Record 18 of Set 2 | taguatinga
# Processing Record 19 of Set 2 | vila franca do campo
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | fairbanks
# Processing Record 22 of Set 2 | laguna
# Processing Record 23 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 2 | jaca
# Processing Record 25 of Set 2 | qaanaaq
# Processing Record 26 of Set 2 | gijon
# Processing Record 27 of Set 2 | georgetown
# Processing Record 28 of Set 2 | san ramon
# Processing Record 29 of Set 2 | saint augustine
# Processing Record 30 of Set 2 | kieta
# Processing Record 31 of Set 2 | chapais
# Processing Record 32 of Set 2 | rawson
# Processing Record 33 of Set 2 | khormuj
# City not found. Skipping...
# Processing Record 34 of Set 2 | najran
# Processing Record 35 of Set 2 | monrovia
# Processing Record 36 of Set 2 | cabo san lucas
# Processing Record 37 of Set 2 | hobart
# Processing Record 38 of Set 2 | ahmadpur east
# Processing Record 39 of Set 2 | snezhnogorsk
# Processing Record 40 of Set 2 | iralaya
# Processing Record 41 of Set 2 | sorong
# Processing Record 42 of Set 2 | roald
# Processing Record 43 of Set 2 | lebu
# Processing Record 44 of Set 2 | new norfolk
# Processing Record 45 of Set 2 | ancud
# Processing Record 46 of Set 2 | riyadh
# Processing Record 47 of Set 2 | santa rosalia
# Processing Record 48 of Set 2 | barrow
# Processing Record 49 of Set 2 | kapaa
# Processing Record 50 of Set 2 | broken hill
# Processing Record 1 of Set 3 | bulungu
# Processing Record 2 of Set 3 | bengkulu
# Processing Record 3 of Set 3 | maniitsoq
# Processing Record 4 of Set 3 | jardim
# Processing Record 5 of Set 3 | tilichiki
# Processing Record 6 of Set 3 | thompson
# Processing Record 7 of Set 3 | pochutla
# Processing Record 8 of Set 3 | opobo
# City not found. Skipping...
# Processing Record 9 of Set 3 | ribeira grande
# Processing Record 10 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 11 of Set 3 | tuktoyaktuk
# Processing Record 12 of Set 3 | itoman
# Processing Record 13 of Set 3 | mareeba
# Processing Record 14 of Set 3 | arraial do cabo
# Processing Record 15 of Set 3 | tommot
# Processing Record 16 of Set 3 | bambous virieux
# Processing Record 17 of Set 3 | stillwater
# Processing Record 18 of Set 3 | great yarmouth
# Processing Record 19 of Set 3 | isangel
# Processing Record 20 of Set 3 | manta
# Processing Record 21 of Set 3 | rivne
# Processing Record 22 of Set 3 | nanortalik
# Processing Record 23 of Set 3 | castro
# Processing Record 24 of Set 3 | kavieng
# Processing Record 25 of Set 3 | phan thiet
# Processing Record 26 of Set 3 | ketchikan
# Processing Record 27 of Set 3 | pevek
# Processing Record 28 of Set 3 | avarua
# Processing Record 29 of Set 3 | hermanus
# Processing Record 30 of Set 3 | butaritari
# Processing Record 31 of Set 3 | longyearbyen
# Processing Record 32 of Set 3 | villa carlos paz
# Processing Record 33 of Set 3 | monduli
# Processing Record 34 of Set 3 | bilibino
# Processing Record 35 of Set 3 | maykain
# City not found. Skipping...
# Processing Record 36 of Set 3 | darhan
# Processing Record 37 of Set 3 | vaini
# Processing Record 38 of Set 3 | okitipupa
# Processing Record 39 of Set 3 | bastia
# Processing Record 40 of Set 3 | jogindarnagar
# Processing Record 41 of Set 3 | kaitangata
# Processing Record 42 of Set 3 | ahipara
# Processing Record 43 of Set 3 | nambucca heads
# Processing Record 44 of Set 3 | jamestown
# Processing Record 45 of Set 3 | nantucket
# Processing Record 46 of Set 3 | kununurra
# Processing Record 47 of Set 3 | ponta do sol
# Processing Record 48 of Set 3 | los llanos de aridane
# Processing Record 49 of Set 3 | shu
# Processing Record 50 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 4 | brokopondo
# Processing Record 2 of Set 4 | benghazi
# Processing Record 3 of Set 4 | tsabong
# Processing Record 4 of Set 4 | nuuk
# Processing Record 5 of Set 4 | skjervoy
# Processing Record 6 of Set 4 | artyk
# City not found. Skipping...
# Processing Record 7 of Set 4 | teshie
# Processing Record 8 of Set 4 | khandyga
# Processing Record 9 of Set 4 | maicao
# Processing Record 10 of Set 4 | chipinge
# Processing Record 11 of Set 4 | payo
# Processing Record 12 of Set 4 | faanui
# Processing Record 13 of Set 4 | ulaanbaatar
# Processing Record 14 of Set 4 | crotone
# Processing Record 15 of Set 4 | pisco
# Processing Record 16 of Set 4 | san quintin
# Processing Record 17 of Set 4 | sabang
# Processing Record 18 of Set 4 | leh
# Processing Record 19 of Set 4 | albany
# Processing Record 20 of Set 4 | sitka
# Processing Record 21 of Set 4 | tucupita
# Processing Record 22 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 4 | mantua
# Processing Record 24 of Set 4 | boueni
# Processing Record 25 of Set 4 | thinadhoo
# Processing Record 26 of Set 4 | kirakira
# Processing Record 27 of Set 4 | harper
# Processing Record 28 of Set 4 | souillac
# Processing Record 29 of Set 4 | nizwa
# Processing Record 30 of Set 4 | hoi an
# Processing Record 31 of Set 4 | mahebourg
# Processing Record 32 of Set 4 | imeni poliny osipenko
# Processing Record 33 of Set 4 | bandar-e lengeh
# Processing Record 34 of Set 4 | brumunddal
# Processing Record 35 of Set 4 | breves
# Processing Record 36 of Set 4 | port elizabeth
# Processing Record 37 of Set 4 | coquimbo
# Processing Record 38 of Set 4 | chillicothe
# Processing Record 39 of Set 4 | goderich
# Processing Record 40 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 4 | jijiga
# Processing Record 42 of Set 4 | acajutla
# Processing Record 43 of Set 4 | tecoanapa
# Processing Record 44 of Set 4 | saldanha
# Processing Record 45 of Set 4 | kidal
# Processing Record 46 of Set 4 | ilulissat
# Processing Record 47 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 4 | chuy
# Processing Record 49 of Set 4 | ponta delgada
# Processing Record 50 of Set 4 | northam
# Processing Record 1 of Set 5 | aklavik
# Processing Record 2 of Set 5 | pangkalanbuun
# Processing Record 3 of Set 5 | saint pete beach
# Processing Record 4 of Set 5 | reno
# Processing Record 5 of Set 5 | san patricio
# Processing Record 6 of Set 5 | amuntai
# Processing Record 7 of Set 5 | sola
# Processing Record 8 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 9 of Set 5 | south lake tahoe
# Processing Record 10 of Set 5 | palmerston
# Processing Record 11 of Set 5 | benicarlo
# Processing Record 12 of Set 5 | olga
# Processing Record 13 of Set 5 | lagoa
# Processing Record 14 of Set 5 | tazovskiy
# Processing Record 15 of Set 5 | bethel
# Processing Record 16 of Set 5 | paranga
# Processing Record 17 of Set 5 | marzuq
# Processing Record 18 of Set 5 | ostrovnoy
# Processing Record 19 of Set 5 | sabya
# Processing Record 20 of Set 5 | gracac
# Processing Record 21 of Set 5 | constantine
# Processing Record 22 of Set 5 | annau
# Processing Record 23 of Set 5 | ornskoldsvik
# Processing Record 24 of Set 5 | bungu
# Processing Record 25 of Set 5 | coihaique
# Processing Record 26 of Set 5 | samarai
# Processing Record 27 of Set 5 | soubre
# Processing Record 28 of Set 5 | port lincoln
# Processing Record 29 of Set 5 | norman wells
# Processing Record 30 of Set 5 | aguimes
# Processing Record 31 of Set 5 | cidreira
# Processing Record 32 of Set 5 | pasighat
# Processing Record 33 of Set 5 | te anau
# Processing Record 34 of Set 5 | clyde river
# Processing Record 35 of Set 5 | anar darreh
# City not found. Skipping...
# Processing Record 36 of Set 5 | yudong
# Processing Record 37 of Set 5 | kruisfontein
# Processing Record 38 of Set 5 | eston
# Processing Record 39 of Set 5 | manaure
# Processing Record 40 of Set 5 | igarka
# Processing Record 41 of Set 5 | pacific grove
# Processing Record 42 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 5 | saint-philippe
# Processing Record 44 of Set 5 | linqiong
# Processing Record 45 of Set 5 | karaton
# Processing Record 46 of Set 5 | codrington
# Processing Record 47 of Set 5 | rio de janeiro
# Processing Record 48 of Set 5 | fuling
# Processing Record 49 of Set 5 | usevya
# Processing Record 50 of Set 5 | lewisburg
# Processing Record 1 of Set 6 | jalu
# Processing Record 2 of Set 6 | alice springs
# Processing Record 3 of Set 6 | zheleznodorozhnyy
# Processing Record 4 of Set 6 | muros
# Processing Record 5 of Set 6 | hasaki
# Processing Record 6 of Set 6 | kuytun
# Processing Record 7 of Set 6 | olafsvik
# Processing Record 8 of Set 6 | valparaiso
# Processing Record 9 of Set 6 | hammerfest
# Processing Record 10 of Set 6 | talnakh
# Processing Record 11 of Set 6 | cockburn town
# Processing Record 12 of Set 6 | caravelas
# Processing Record 13 of Set 6 | porvoo
# Processing Record 14 of Set 6 | sao bento
# Processing Record 15 of Set 6 | tharad
# Processing Record 16 of Set 6 | vestmannaeyjar
# Processing Record 17 of Set 6 | angra
# City not found. Skipping...
# Processing Record 18 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 6 | bara
# Processing Record 20 of Set 6 | urumqi
# Processing Record 21 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 6 | sechura
# Processing Record 23 of Set 6 | nioro
# Processing Record 24 of Set 6 | nikolskoye
# Processing Record 25 of Set 6 | afyonkarahisar
# Processing Record 26 of Set 6 | fuyu
# Processing Record 27 of Set 6 | bongor
# Processing Record 28 of Set 6 | praya
# Processing Record 29 of Set 6 | san cristobal
# Processing Record 30 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 31 of Set 6 | dubbo
# Processing Record 32 of Set 6 | serenje
# Processing Record 33 of Set 6 | novyy urengoy
# Processing Record 34 of Set 6 | azle
# Processing Record 35 of Set 6 | beringovskiy
# Processing Record 36 of Set 6 | kralendijk
# Processing Record 37 of Set 6 | luderitz
# Processing Record 38 of Set 6 | altay
# Processing Record 39 of Set 6 | nizhnyaya tavda
# Processing Record 40 of Set 6 | seoul
# Processing Record 41 of Set 6 | salalah
# Processing Record 42 of Set 6 | raudeberg
# Processing Record 43 of Set 6 | bayanday
# Processing Record 44 of Set 6 | faya
# Processing Record 45 of Set 6 | amaraji
# Processing Record 46 of Set 6 | alta floresta
# Processing Record 47 of Set 6 | tiznit
# Processing Record 48 of Set 6 | linchuan
# City not found. Skipping...
# Processing Record 49 of Set 6 | oranjemund
# Processing Record 50 of Set 6 | kenitra
# Processing Record 1 of Set 7 | saint anthony
# Processing Record 2 of Set 7 | shediac
# Processing Record 3 of Set 7 | matagami
# Processing Record 4 of Set 7 | nome
# Processing Record 5 of Set 7 | torres
# Processing Record 6 of Set 7 | barroualie
# City not found. Skipping...
# Processing Record 7 of Set 7 | gobabis
# Processing Record 8 of Set 7 | tahe
# Processing Record 9 of Set 7 | lebork
# Processing Record 10 of Set 7 | necochea
# Processing Record 11 of Set 7 | colombia
# Processing Record 12 of Set 7 | banposh
# Processing Record 13 of Set 7 | ossora
# Processing Record 14 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 15 of Set 7 | praia da vitoria
# Processing Record 16 of Set 7 | hwange
# Processing Record 17 of Set 7 | kudahuvadhoo
# Processing Record 18 of Set 7 | bayangol
# Processing Record 19 of Set 7 | yerbogachen
# Processing Record 20 of Set 7 | dwarka
# Processing Record 21 of Set 7 | antofagasta
# Processing Record 22 of Set 7 | tyukhtet
# Processing Record 23 of Set 7 | elat
# Processing Record 24 of Set 7 | geraldton
# Processing Record 25 of Set 7 | danielskuil
# Processing Record 26 of Set 7 | neryungri
# Processing Record 27 of Set 7 | bjala
# City not found. Skipping...
# Processing Record 28 of Set 7 | sandpoint
# Processing Record 29 of Set 7 | mitu
# Processing Record 30 of Set 7 | hermon
# Processing Record 31 of Set 7 | mairana
# Processing Record 32 of Set 7 | sao felix do xingu
# Processing Record 33 of Set 7 | cabedelo
# Processing Record 34 of Set 7 | pyapon
# Processing Record 35 of Set 7 | mayo
# Processing Record 36 of Set 7 | mount isa
# Processing Record 37 of Set 7 | togur
# Processing Record 38 of Set 7 | olinda
# Processing Record 39 of Set 7 | artyom
# Processing Record 40 of Set 7 | baykit
# Processing Record 41 of Set 7 | manbij
# Processing Record 42 of Set 7 | rosarito
# Processing Record 43 of Set 7 | shingu
# Processing Record 44 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 45 of Set 7 | thunder bay
# Processing Record 46 of Set 7 | anloga
# Processing Record 47 of Set 7 | husavik
# Processing Record 48 of Set 7 | naryan-mar
# Processing Record 49 of Set 7 | qasigiannguit
# Processing Record 50 of Set 7 | lovec
# City not found. Skipping...
# Processing Record 1 of Set 8 | hamilton
# Processing Record 2 of Set 8 | buluang
# Processing Record 3 of Set 8 | mushie
# Processing Record 4 of Set 8 | omsukchan
# Processing Record 5 of Set 8 | berlevag
# Processing Record 6 of Set 8 | saint george
# Processing Record 7 of Set 8 | emba
# Processing Record 8 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 9 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 8 | karakendzha
# City not found. Skipping...
# Processing Record 11 of Set 8 | alofi
# Processing Record 12 of Set 8 | glenwood springs
# Processing Record 13 of Set 8 | yelizovo
# Processing Record 14 of Set 8 | umm kaddadah
# Processing Record 15 of Set 8 | khargone
# Processing Record 16 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 8 | acarau
# Processing Record 18 of Set 8 | port blair
# Processing Record 19 of Set 8 | esperance
# Processing Record 20 of Set 8 | kashi
# Processing Record 21 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 22 of Set 8 | grindavik
# Processing Record 23 of Set 8 | derzhavinsk
# Processing Record 24 of Set 8 | feira nova
# Processing Record 25 of Set 8 | clarence town
# Processing Record 26 of Set 8 | port augusta
# Processing Record 27 of Set 8 | willowmore
# Processing Record 28 of Set 8 | huicheng
# Processing Record 29 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 30 of Set 8 | bolobo
# Processing Record 31 of Set 8 | mokrousovo
# Processing Record 32 of Set 8 | general pico
# Processing Record 33 of Set 8 | kantunilkin
# Processing Record 34 of Set 8 | mount gambier
# Processing Record 35 of Set 8 | poya
# Processing Record 36 of Set 8 | kutum
# Processing Record 37 of Set 8 | amli
# Processing Record 38 of Set 8 | zavodoukovsk
# Processing Record 39 of Set 8 | krasnoselkup
# Processing Record 40 of Set 8 | vostok
# Processing Record 41 of Set 8 | srednekolymsk
# Processing Record 42 of Set 8 | olavarria
# Processing Record 43 of Set 8 | norman
# Processing Record 44 of Set 8 | senneterre
# Processing Record 45 of Set 8 | cayenne
# Processing Record 46 of Set 8 | russkaya polyana
# Processing Record 47 of Set 8 | pfarrkirchen
# Processing Record 48 of Set 8 | batemans bay
# Processing Record 49 of Set 8 | regina
# Processing Record 50 of Set 8 | tiksi
# Processing Record 1 of Set 9 | kholodnyy
# Processing Record 2 of Set 9 | ruzhyn
# Processing Record 3 of Set 9 | tautira
# Processing Record 4 of Set 9 | itarema
# Processing Record 5 of Set 9 | narsaq
# Processing Record 6 of Set 9 | diamantino
# Processing Record 7 of Set 9 | lompoc
# Processing Record 8 of Set 9 | babu
# Processing Record 9 of Set 9 | tumut
# Processing Record 10 of Set 9 | torbay
# Processing Record 11 of Set 9 | broome
# Processing Record 12 of Set 9 | wad rawah
# Processing Record 13 of Set 9 | jacareacanga
# Processing Record 14 of Set 9 | rio grande
# Processing Record 15 of Set 9 | iranshahr
# Processing Record 16 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 9 | port moresby
# Processing Record 18 of Set 9 | constitucion
# Processing Record 19 of Set 9 | zaqatala
# Processing Record 20 of Set 9 | reforma
# Processing Record 21 of Set 9 | lindi
# Processing Record 22 of Set 9 | hailey
# Processing Record 23 of Set 9 | buchanan
# Processing Record 24 of Set 9 | gat
# Processing Record 25 of Set 9 | bahia honda
# Processing Record 26 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set 9 | axim
# Processing Record 28 of Set 9 | mbekenyera
# Processing Record 29 of Set 9 | phalodi
# Processing Record 30 of Set 9 | cherskiy
# Processing Record 31 of Set 9 | poum
# Processing Record 32 of Set 9 | codajas
# Processing Record 33 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 34 of Set 9 | marsh harbour
# Processing Record 35 of Set 9 | manono
# Processing Record 36 of Set 9 | alekseyevka
# Processing Record 37 of Set 9 | aykhal
# Processing Record 38 of Set 9 | emerald
# Processing Record 39 of Set 9 | warri
# Processing Record 40 of Set 9 | peleduy
# Processing Record 41 of Set 9 | dali
# Processing Record 42 of Set 9 | avera
# Processing Record 43 of Set 9 | kachiry
# Processing Record 44 of Set 9 | khanskaya
# Processing Record 45 of Set 9 | felanitx
# Processing Record 46 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 47 of Set 9 | severo-yeniseyskiy
# Processing Record 48 of Set 9 | launceston
# Processing Record 49 of Set 9 | lichinga
# Processing Record 50 of Set 9 | pakxe
# Processing Record 1 of Set 10 | balinsasayao
# Processing Record 2 of Set 10 | jining
# Processing Record 3 of Set 10 | la ronge
# Processing Record 4 of Set 10 | porbandar
# Processing Record 5 of Set 10 | aden
# Processing Record 6 of Set 10 | vallenar
# Processing Record 7 of Set 10 | nemuro
# Processing Record 8 of Set 10 | fomboni
# Processing Record 9 of Set 10 | takoradi
# Processing Record 10 of Set 10 | dumas
# Processing Record 11 of Set 10 | ballina
# Processing Record 12 of Set 10 | margate
# Processing Record 13 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 14 of Set 10 | beyneu
# Processing Record 15 of Set 10 | anori
# Processing Record 16 of Set 10 | bichura
# Processing Record 17 of Set 10 | oistins
# Processing Record 18 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 19 of Set 10 | taoudenni
# Processing Record 20 of Set 10 | swellendam
# Processing Record 21 of Set 10 | jacqueville
# Processing Record 22 of Set 10 | lingyuan
# Processing Record 23 of Set 10 | hopkinsville
# Processing Record 24 of Set 10 | vardo
# Processing Record 25 of Set 10 | porto seguro
# Processing Record 26 of Set 10 | bernal
# Processing Record 27 of Set 10 | barreiras
# Processing Record 28 of Set 10 | kuching
# Processing Record 29 of Set 10 | abha
# Processing Record 30 of Set 10 | sistranda
# Processing Record 31 of Set 10 | darnah
# Processing Record 32 of Set 10 | bure
# Processing Record 33 of Set 10 | tucuman
# Processing Record 34 of Set 10 | knarvik
# Processing Record 35 of Set 10 | marondera
# Processing Record 36 of Set 10 | agadez
# Processing Record 37 of Set 10 | tuatapere
# Processing Record 38 of Set 10 | gold coast
# Processing Record 39 of Set 10 | dongargaon
# Processing Record 40 of Set 10 | dingle
# Processing Record 41 of Set 10 | lethem
# Processing Record 42 of Set 10 | nassau
# Processing Record 43 of Set 10 | alihe
# Processing Record 44 of Set 10 | whitehorse
# Processing Record 45 of Set 10 | kyra
# Processing Record 46 of Set 10 | norwich
# Processing Record 47 of Set 10 | da nang
# Processing Record 48 of Set 10 | salihorsk
# Processing Record 49 of Set 10 | viedma
# Processing Record 50 of Set 10 | bezlyudivka
# Processing Record 1 of Set 11 | airai
# Processing Record 2 of Set 11 | bilma
# Processing Record 3 of Set 11 | saint-joseph
# Processing Record 4 of Set 11 | hervey bay
# Processing Record 5 of Set 11 | kavaratti
# Processing Record 6 of Set 11 | chicama
# Processing Record 7 of Set 11 | muzhi
# Processing Record 8 of Set 11 | bundaberg
# Processing Record 9 of Set 11 | hambantota
# Processing Record 10 of Set 11 | lincoln
# Processing Record 11 of Set 11 | ashti
# Processing Record 12 of Set 11 | sainte-rose
# Processing Record 13 of Set 11 | jambi
# Processing Record 14 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 15 of Set 11 | slave lake
# Processing Record 16 of Set 11 | taksimo
# Processing Record 17 of Set 11 | puerto leguizamo
# Processing Record 18 of Set 11 | isabela
# Processing Record 19 of Set 11 | lavrentiya
# Processing Record 20 of Set 11 | los palmitos
# Processing Record 21 of Set 11 | yulara
# Processing Record 22 of Set 11 | naze
# Processing Record 23 of Set 11 | camacha
# Processing Record 24 of Set 11 | henderson
# Processing Record 25 of Set 11 | calamar
# Processing Record 26 of Set 11 | ous
# Processing Record 27 of Set 11 | stamsund
# City not found. Skipping...
# Processing Record 28 of Set 11 | yarada
# Processing Record 29 of Set 11 | mehamn
# Processing Record 30 of Set 11 | saryg-sep
# Processing Record 31 of Set 11 | okhotsk
# Processing Record 32 of Set 11 | burica
# City not found. Skipping...
# Processing Record 33 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 11 | bowling green
# Processing Record 35 of Set 11 | deputatskiy
# Processing Record 36 of Set 11 | bairiki
# Processing Record 37 of Set 11 | college
# Processing Record 38 of Set 11 | kapit
# Processing Record 39 of Set 11 | alexandria
# Processing Record 40 of Set 11 | ambon
# Processing Record 41 of Set 11 | negombo
# Processing Record 42 of Set 11 | stykkisholmur
# Processing Record 43 of Set 11 | sur
# Processing Record 44 of Set 11 | cuamba
# Processing Record 45 of Set 11 | eureka
# Processing Record 46 of Set 11 | catamarca
# Processing Record 47 of Set 11 | pangai
# Processing Record 48 of Set 11 | bonavista
# Processing Record 49 of Set 11 | piacabucu
# Processing Record 50 of Set 11 | san andres
# Processing Record 1 of Set 12 | fort nelson
# Processing Record 2 of Set 12 | rocha
# Processing Record 3 of Set 12 | karasburg
# Processing Record 4 of Set 12 | diplo
# Processing Record 5 of Set 12 | bud
# Processing Record 6 of Set 12 | estevan
# Processing Record 7 of Set 12 | port hardy
# Processing Record 8 of Set 12 | podbelsk
# City not found. Skipping...
# Processing Record 9 of Set 12 | placido de castro
# Processing Record 10 of Set 12 | smidovich
# Processing Record 11 of Set 12 | namtsy
# Processing Record 12 of Set 12 | fortuna
# Processing Record 13 of Set 12 | xam nua
# Processing Record 14 of Set 12 | mataram
# Processing Record 15 of Set 12 | pitimbu
# Processing Record 16 of Set 12 | kalmunai
# Processing Record 17 of Set 12 | khurai
# Processing Record 18 of Set 12 | vila do maio
# Processing Record 19 of Set 12 | linxia
# Processing Record 20 of Set 12 | amot
# Processing Record 21 of Set 12 | paamiut
# Processing Record 22 of Set 12 | mahanoro
# Processing Record 23 of Set 12 | lodja
# Processing Record 24 of Set 12 | kathmandu
# Processing Record 25 of Set 12 | reyes
# Processing Record 26 of Set 12 | sao filipe
# Processing Record 27 of Set 12 | hvammstangi
# City not found. Skipping...
# Processing Record 28 of Set 12 | mananjary
# Processing Record 29 of Set 12 | lakatoro
# Processing Record 30 of Set 12 | carutapera
# Processing Record 31 of Set 12 | mendi
# Processing Record 32 of Set 12 | lodhran
# Processing Record 33 of Set 12 | longhua
# Processing Record 34 of Set 12 | aksarka
# Processing Record 35 of Set 12 | umm lajj
# Processing Record 36 of Set 12 | sibolga
# Processing Record 37 of Set 12 | verkhnevilyuysk
# Processing Record 38 of Set 12 | razole
# Processing Record 39 of Set 12 | aripuana
# Processing Record 40 of Set 12 | kroderen
# City not found. Skipping...
# Processing Record 41 of Set 12 | safford
# Processing Record 42 of Set 12 | nagato
# Processing Record 43 of Set 12 | litoral del san juan
# City not found. Skipping...
# Processing Record 44 of Set 12 | nabire
# Processing Record 45 of Set 12 | ixtapa
# Processing Record 46 of Set 12 | kepno
# Processing Record 47 of Set 12 | sao joao da barra
# Processing Record 48 of Set 12 | itea
# Processing Record 49 of Set 12 | alakurtti
# Processing Record 50 of Set 12 | banda aceh
# Processing Record 1 of Set 13 | bacuit
# City not found. Skipping...
# Processing Record 2 of Set 13 | sakakah
# Processing Record 3 of Set 13 | havoysund
# Processing Record 4 of Set 13 | guerrero negro
# Processing Record 5 of Set 13 | strathroy
# Processing Record 6 of Set 13 | sicuani
# Processing Record 7 of Set 13 | dalnerechensk
# Processing Record 8 of Set 13 | ano mera
# Processing Record 9 of Set 13 | aizkraukle
# Processing Record 10 of Set 13 | richards bay
# Processing Record 11 of Set 13 | saint-andre-avellin
# Processing Record 12 of Set 13 | zhigansk
# Processing Record 13 of Set 13 | limbang
# Processing Record 14 of Set 13 | celestun
# Processing Record 15 of Set 13 | grimma
# Processing Record 16 of Set 13 | cairns
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# 565

# %%
#Save the new DataFrame as a CSV file
challenge_city_data_df = pd.DataFrame(city_data)
challenge_city_data_df.to_csv(path_or_buf='data/WeatherPy_challenge.csv', index_label='City_ID')

# %% [markdown]
# # There were 82 cities that recorded ranfall and 11 cities that recorded snow

# %%
# How many cities have recorded rainfall?
raining_count = challenge_city_data_df.loc[(challenge_city_data_df['Rain inches (last 3 hrs)']!=0)].count()
raining_count
# Out:
# City                        81
# Country                     81
# Date                        81
# Lat                         81
# Lng                         81
# Max Temp                    81
# Humidity                    81
# Cloudiness                  81
# Wind Speed                  81
# Current Description         81
# Rain inches (last 3 hrs)    81
# Snow inches (last 3 hrs)    81
# dtype: int64

# %%
# How many cities have recorded snow?
snowing_count = challenge_city_data_df.loc[(challenge_city_data_df['Snow inches (last 3 hrs)']!=0)].count()
snowing_count
# Out:
# City                        11
# Country                     11
# Date                        11
# Lat                         11
# Lng                         11
# Max Temp                    11
# Humidity                    11
# Cloudiness                  11
# Wind Speed                  11
# Current Description         11
# Rain inches (last 3 hrs)    11
# Snow inches (last 3 hrs)    11
# dtype: int64
